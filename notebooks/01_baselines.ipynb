# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

processed_dir = Path("../data/processed")

train = pd.read_csv(processed_dir / "train.csv")
val = pd.read_csv(processed_dir / "val.csv")
test = pd.read_csv(processed_dir / "test.csv")

train.head()
# Out:
#            id                                               text        label
# 0   2635.json  Says the Annies List political group supports ...        false
# 1  10540.json  When did the decline of coal start? It started...    half-true
# 2    324.json  Hillary Clinton agrees with John McCain "by vo...  mostly-true
# 3   1123.json  Health care reform legislation is likely to ma...        false
# 4   9028.json  The economic turnaround started at the end of ...    half-true

# %%
plt.figure(figsize=(8,5))
train['label'].value_counts().plot(kind='bar')
plt.title("Label Distribution in Train Set")
plt.xlabel("Labels")
plt.ylabel("Count")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

train = pd.read_csv("../data/processed/train.csv")
val = pd.read_csv("../data/processed/val.csv")

# 1️⃣ Class distribution
train['label'].value_counts().plot(kind='bar', figsize=(8,5), title="Train Label Distribution")
plt.show()

# 2️⃣ Text lengths
train['text'].str.len().hist(bins=50, figsize=(8,5))
plt.title("Train Text Length Distribution")
plt.xlabel("Number of characters")
plt.ylabel("Number of samples")
plt.show()

# %%
train['text_length'] = train['text'].str.len()
train['text_length'].describe()
# Out:
# count    10240.000000
# mean       106.918750
# std         59.917722
# min         11.000000
# 25%         73.000000
# 50%         99.000000
# 75%        132.250000
# max       3192.000000
# Name: text_length, dtype: float64

# %%
train.isna().sum(), val.isna().sum(), test.isna().sum()
# Out:
# (id             0
#  text           0
#  label          0
#  text_length    0
#  dtype: int64,
#  id       0
#  text     0
#  label    0
#  dtype: int64,
#  id       0
#  text     0
#  label    0
#  dtype: int64)
