# %%
import pandas as pd
train = pd.read_csv("../data/processed/train.csv")
print(train.columns)
# Out:
# Index(['id', 'text', 'label'], dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# Load processed CSVs
train = pd.read_csv("../data/processed/train.csv")
val = pd.read_csv("../data/processed/val.csv")
test = pd.read_csv("../data/processed/test.csv")

# 1️⃣ Class distribution
plt.figure(figsize=(8,5))
train['label'].value_counts().plot(kind='bar')
plt.title("Train Set Label Distribution")
plt.show()

# 2️⃣ Statement length distribution
train['statement_len'] = train['text'].str.len()
plt.figure(figsize=(8,5))
sns.histplot(train['statement_len'], bins=30, kde=True)
plt.title("Statement Length Distribution")
plt.show()

# 3️⃣ Missing values
print("Missing values per column:")
print(train.isna().sum())

# 4️⃣ Peek at data
train.head()
# Out:
# Missing values per column:
# id               0
# text             0
# label            0
# statement_len    0
# dtype: int64
#            id                                               text        label  \
# 0   2635.json  Says the Annies List political group supports ...        false
# 1  10540.json  When did the decline of coal start? It started...    half-true
# 2    324.json  Hillary Clinton agrees with John McCain "by vo...  mostly-true
# 3   1123.json  Health care reform legislation is likely to ma...        false
# 4   9028.json  The economic turnaround started at the end of ...    half-true
#
#    statement_len
# 0             82
# 1            141
# 2            105
# 3             78
# 4             54
